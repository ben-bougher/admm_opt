# %%
from avo_fit import *
from horizon_parse import *

import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
horizonB = horizon_norm(parse_horizon('/Users/bbougher/data/Penobscot/AVO_horizonB.hor')).T
labelsB = np.zeros(horizonB.shape[1])
horizonC = horizon_norm(parse_horizon('/Users/bbougher/data/Penobscot/AVO_horizonC.hor')).T
labelsC = np.ones(horizonC.shape[1])
horizonD = horizon_norm(parse_horizon('/Users/bbougher/data/Penobscot/AVO_horizonD.hor')).T
labelsD = np.ones(horizonD.shape[1])*2

# %%
data = np.hstack((horizonB[:,::100], horizonC[:,::100], horizonD[:,::100]))

# %%
X = data
Y = X

# %%
T, obj = minimizer(X, Y, beta=80.0, zeta=2000.0, delta=3000.0, 
                   max_iter=5000, tol=0.0, v=50.0)

# %%
plt.figure()
plt.subplot(121)
plt.imshow(X, aspect='auto', interpolation=None)
plt.subplot(122)
plt.imshow(X.dot(T), aspect='auto', interpolation=None)

# %%
plt.figure()
plt.semilogy(obj)
plt.figure()
plt.pcolor(T)
