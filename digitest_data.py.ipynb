# %%
from avo_fit import *
from matplotlib import pyplot as plt
import numpy as np
from scipy.io import loadmat
# %matplotlib inline

# %%
data = loadmat('/Users/bbougher/src/digi_testing/ubc_int_grad_test1.mat')

# %%
traces = data['vol_traces']
flat_traces = np.reshape(traces, (traces.shape[0] * traces.shape[1], traces.shape[2])).T

# %%
energy = np.sum(flat_traces**2,0) / 8.0
filtered_traces = flat_traces[:,energy > 5000]
plt.plot(filtered_traces[:, ::20])

# %%
X = filtered_traces
Y = X
X.shape
T, obj = minimizer(X, Y, beta=1000.0, zeta=1.0, delta=2.0, 
                   max_iter=500, tol=0.0, v=50.0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-1eb9b0a4fb95> in <module>()
#       3 X.shape
#       4 T, obj = minimizer(X, Y, beta=1000.0, zeta=1.0, delta=2.0,
# ----> 5                    max_iter=500, tol=0.0, v=50.0)
#
# /Volumes/Users/bbougher/sandbox/admm_opt/avo_fit.pyc in minimizer(X, Y, beta, delta, zeta, h, v, tol, max_iter)
#      88         Z_kp1 = Z_update(beta, Y, delta, X, Tk, Pk)
#      89
# ---> 90         T_kp1 = T_update(Z_kp1, Pk, Rw, delta, sigma, zeta)
#      91
#      92
#
# /Volumes/Users/bbougher/sandbox/admm_opt/avo_fit.pyc in T_update(Z_kp1, Pk, Rw, delta, sigma, zeta)
#      21
#      22     T1 = Z_kp1 +(Pk / delta) - (Rw.dot(sigma) / delta)
# ---> 23     T2 = conv_proj(T1, delta, zeta)
#      24
#      25     return T1 - T2
#
# /Volumes/Users/bbougher/sandbox/admm_opt/avo_fit.pyc in conv_proj(A, delta, zeta)
# ...

# %%
plt.semilogy(obj)
